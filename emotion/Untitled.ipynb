# %%
import cv2

# %%
img = cv2.imread('happy.jpg')

# %%
pip install deepface
# Out:
# ...
#      ------------------------------------- 108.6/108.6 kB 11.1 kB/s eta 0:00:00
# ...
#      -------------------------------------- 11.6/11.6 MB 508.1 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 78.5/78.5 kB 1.5 MB/s eta 0:00:00
# ...
#   Using cached tensorflow-2.18.0-cp311-cp311-win_amd64.whl (7.5 kB)
# ...
#      ---------------------------------------- 1.2/1.2 MB 1.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 103.0/103.0 kB 1.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.9/1.9 MB 1.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 87.2/87.2 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 85.0/85.0 kB 2.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 224.5/224.5 kB 1.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 97.9/97.9 kB 1.9 MB/s eta 0:00:00
# ...

# %%
pip install deepface --user
# Out:
# ...
#
#   Using cached deepface-0.0.93-py3-none-any.whl (108 kB)
# ...
#   Using cached pandas-2.2.3-cp311-cp311-win_amd64.whl (11.6 MB)
# ...
#   Using cached gdown-5.2.0-py3-none-any.whl (18 kB)
# ...
#   Using cached tensorflow-2.18.0-cp311-cp311-win_amd64.whl (7.5 kB)
# ...
#   Using cached keras-3.7.0-py3-none-any.whl (1.2 MB)
# ...
#   Using cached flask-3.1.0-py3-none-any.whl (102 kB)
# ...
#   Using cached Flask_Cors-5.0.0-py2.py3-none-any.whl (14 kB)
# ...
#   Using cached mtcnn-1.0.0-py3-none-any.whl (1.9 MB)
# ...
#   Using cached retina_face-0.0.17-py3-none-any.whl (25 kB)
# ...
#   Using cached fire-0.7.0.tar.gz (87 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached gunicorn-23.0.0-py3-none-any.whl (85 kB)
# ...
#   Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# ...
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# ...
#   Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# ...
#   Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# ...

# %%
# %pip install deepface
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pylot as plt
# Out:
# ----------------------------------------------------------------------
# ModuleNotFoundError                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import matplotlib.pylot as plt
#
# ModuleNotFoundError: No module named 'matplotlib.pylot'

# %%
from deepface import DeepFace
# Out:
# ----------------------------------------------------------------------
# ModuleNotFoundError                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from deepface import DeepFace
#
# ModuleNotFoundError: No module named 'deepface'

# %%
from deepface import DeepFace
# Out:
# ----------------------------------------------------------------------
# ModuleNotFoundError                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from deepface import DeepFace
#
# ModuleNotFoundError: No module named 'deepface'

# %%
pip show deepface
# Out:
# Name: deepfaceNote: you may need to restart the kernel to use updated packages.
#
# Version: 0.0.93
# Summary: A Lightweight Face Recognition and Facial Attribute Analysis Framework (Age, Gender, Emotion, Race) for Python
# Home-page: https://github.com/serengil/deepface
# Author: Sefik Ilkin Serengil
# Author-email: serengil@gmail.com
# License: MIT
# Location: C:\Users\Khalilullah Nuraini\AppData\Roaming\Python\Python311\site-packages
# Requires: fire, Flask, flask-cors, gdown, gunicorn, keras, mtcnn, numpy, opencv-python, pandas, Pillow, requests, retina-face, tensorflow, tqdm
# Required-by:

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Khalilullah Nuraini\AppData\Local\Programs\Python\Python311\python.exe

# %%
import sys
sys.path.append(r"C:\Users\Khalilullah Nuraini\AppData\Roaming\Python\Python311\site-packages")
from deepface import DeepFace
# Out:
# ----------------------------------------------------------------------
# ModuleNotFoundError                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\retinaface\commons\package_utils.py:19, in validate_for_keras3()
#      18 try:
# ---> 19     import tf_keras
#      21     logger.debug(f"tf_keras is already available - {tf_keras.__version__}")
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                           Traceback (most recent call last)
# Cell In[16], line 3
#       1 import sys
#       2 sys.path.append(r"C:\Users\Khalilullah Nuraini\AppData\Roaming\Python\Python311\site-packages")
# ----> 3 from deepface import DeepFace
#
# File ~\AppData\Roaming\Python\Python311\site-packages\deepface\DeepFace.py:20
#      18 from deepface.commons import package_utils, folder_utils
#      19 from deepface.commons.logger import Logger
# ...

# %%
C:\Users\Khalilullah Nuraini\AppData\Local\Programs\Python\Python311\python.exe -m pip install deepface
# Out:
#   Cell In[17], line 1
#     C:\Users\Khalilullah Nuraini\AppData\Local\Programs\Python\Python311\python.exe -m pip install deepface
#        ^
# SyntaxError: unexpected character after line continuation character

# %%
# %pip install deepface
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from deepface import DeepFace
# Out:
# ----------------------------------------------------------------------
# ModuleNotFoundError                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\retinaface\commons\package_utils.py:19, in validate_for_keras3()
#      18 try:
# ---> 19     import tf_keras
#      21     logger.debug(f"tf_keras is already available - {tf_keras.__version__}")
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                           Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from deepface import DeepFace
#
# File ~\AppData\Roaming\Python\Python311\site-packages\deepface\DeepFace.py:20
#      18 from deepface.commons import package_utils, folder_utils
#      19 from deepface.commons.logger import Logger
# ---> 20 from deepface.modules import (
#      21     modeling,
#      22     representation,
#      23     verification,
# ...

# %%
pip install tf-keras
# Out:
# ...
#      ---------------------------------------- 1.7/1.7 MB 722.2 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %%
from deepface import DeepFace
# Out:
# WARNING:tensorflow:From C:\Users\Khalilullah Nuraini\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 24-12-05 20:05:32 - Directory C:\Users\Khalilullah Nuraini\.deepface has been created
# 24-12-05 20:05:32 - Directory C:\Users\Khalilullah Nuraini\.deepface\weights has been created

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# ----------------------------------------------------------------------
# NameError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 predictions = DeepFace.analyze(img)
#
# NameError: name 'img' is not defined
